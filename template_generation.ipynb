# %%
import json
import requests

import numpy as np

# %%
a.content
# Out:
# b'<!doctype html>\n<html lang="en">\n\n<head>\n  <meta charset="utf-8">\n  <title>CamFrontend</title>\n  <base href="./">\n\n  <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n  <link rel="icon" type="image/x-icon" href="favicon.ico">\n  <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">\n</head>\n\n<body class="mat-app-background">\n  <app-root></app-root>\n<script type="text/javascript" src="runtime.js"></script><script type="text/javascript" src="polyfills.js"></script><script type="text/javascript" src="styles.js"></script><script type="text/javascript" src="scripts.js"></script><script type="text/javascript" src="vendor.js"></script><script type="text/javascript" src="main.js"></script></body>\n\n</html>'

# %%
import requests

URL = 'http://ltdemos.informatik.uni-hamburg.de/cam-api?fs=false&objectA=dog&objectB=cat&aspect1=size&weight1=3&aspect2=food&weight2=1'

proxies = {
  "http": "http://185.46.212.97:10015/",
  "https": "https://185.46.212.98:10015/",
}


a = requests.get(url=URL, proxies=proxies)
b = a.json()

# %%
URL = 'http://ltdemos.informatik.uni-hamburg.de/cam-api'

proxies = {
  "http": "http://185.46.212.97:10015/",
  "https": "https://185.46.212.98:10015/",
}

def get_response(first_object, second_object, fast_search=True, 
               aspects=None, weights=None):
    num_aspects = len(aspects) if aspects is not None else 0
    num_weights = len(weights) if weights is not None else 0
    if num_aspects != num_weights:
        raise ValueError(
            "Number of weights should be equal to the number of aspects")
    params = {
        'objectA': first_object,
        'objectB': second_object,
        'fs': str(fast_search).lower()
    }
    if num_aspects:
        params.update({'aspect{}'.format(i + 1): aspect 
                       for i, aspect in enumerate(aspects)})
        params.update({'weight{}'.format(i + 1): weight 
                       for i, weight in enumerate(weights)})
    print ("get url")
    response = requests.get(url=URL, params=params, proxies=proxies)
    return response

# %%
'''
Example 
http://ltdemos.informatik.uni-hamburg.de/cam-api?fs=false&objectA=dog&objectB=cat&aspect1=size&weight1=3&aspect2=food&weight2=1
'''

response = get_response('ios', 'android', fast_search=True, aspects=['better'], weights=[1])
# Out:
# get url

# %%
response_json = response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-46-8bd4a409b8c7> in <module>
# ----> 1 response_json = response.json()
#
# /opt/anaconda/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# /opt/anaconda/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /opt/anaconda/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /opt/anaconda/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
filename = "cat_dog_size_3_food_1.json"

with open(filename, 'w+') as f:
    json.dump(response_json, f)

# %%
response_json.keys()
# Out:
# dict_keys(['extractedAspectsObject1', 'extractedAspectsObject2', 'object1', 'object2', 'sentenceCount', 'winner'])

# %%
response_json['object1']['sentences']
# Out:
# [{'CAM_score': 1.3463028668797037,
#   'ES_score': 41.103783,
#   'confidence': 2,
#   'context_aspects': [],
#   'id_pair': {'http://www.phonearena.com/news/Google-Maps-causes-a-spike-in-iOS-6-updates_id37864': 31,
#    'http://www.phonearena.com/news/Google-Maps-causes-a-spike-in-iOS-6-updates_id37864/comments': 25},
#   'text': 'I find ios apps are WAY smoother and work better than android.'},
#  {'CAM_score': 1.2711311856636591,
#   'ES_score': 38.808727,
#   'confidence': 2,
#   'context_aspects': ['smoother', 'windows', 'framework'],
#   'id_pair': {'http://www.androidauthority.com/apple-iphone-5-vs-samsung-galaxy-s3-114213/': 1683},
#   'text': 'its because ios and windows 8 have a better and smoother framework than android.'},
#  {'CAM_score': 1.2428258897006468,
#   'ES_score': 37.944542,
#   'confidence': 2,
#   'context_aspects': ['easier to do', 'easier', 'easier to do', 'easier'],
#   'id_pair': {'http://www.phonearena.com/news/iOS-6-Maps-app-youre-literally-not-going-to-find-things_id34644': 46,
#    'http://www.phonearena.com/news/iOS-6-Maps-app-youre-literally-not-going-to-find-things_id34644/comments/page/1': 32},
#   'text': 'iOS is much easier to do, and looks better, than android apps.'},
#  {'CAM_score': 1.2347943764045421,
#   'ES_score': 37.699333,
#   'confidence': 2,
#   'context_aspects': ['smoother'],
#   'id_pair': {'http://bgr.com/2011/03/18/apple-ipad-2-review/': 202},
#   'text': '6) IOS IS a much smoother OS, and just works better, much better than the Android OS.'},
#  {'CAM_score': 0.7734587487368109,
#   'ES_score': 47.22872,
#   'confidence': 1,
#   'context_aspects': ['easier to use', 'easier', 'easier to use', 'easier'],
#   'id_pair': {'http://lifelibertytech.com/2013/01/28/life-is-hard-android-is-harder/': 29},
#   'text': 'iOS is easier to use than Android.'},
#  {'CAM_score': 0.7433255808491992,
#   'ES_score': 45.388737,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://modmyi.com/content/12427-googles-eric-schmidt-android-more-secure-than-iphone.html?p=6952491': 100,
#    'http://modmyi.com/forums/iphone-news/830173-googles-eric-schmidt-android-more-secure-than-iphone-2.html': 94},
#   'text': "And BlackBerry is okay, but it's way worse than iOS."},
#  {'CAM_score': 0.740335753409362,
#   'ES_score': 45.206173,
#   'confidence': 1,
#   'context_aspects': ['faster'],
#   'id_pair': {'http://marketingland.com/mobile-browser-speed-battle-ios-devices-faster-on-3g-android-faster-on-lte-23364': 11},
#   'text': "On the slower 3G cellular network, which is how more than half the world's mobile users access the web, iOS devices performed better than their Android counterparts."},
#  {'CAM_score': 0.7331051510866432,
#   'ES_score': 44.76466,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://apple.slashdot.org/story/12/10/01/1527257/ask-steve-wozniak-anything/interesting-comments': 99,
#    'http://apple.slashdot.org/story/12/10/01/1527257/ask-steve-wozniak-anything?sdsrc=next': 35,
#    'http://gizmodo.com/5948099/five-things-woz-would-do-with-apple-right-now-itunes-on-android-less-lawsuits-and-more?tag=apple': 22,
#    'http://www.slashgear.com/woz-tells-fan-community-to-chill-out-02250110/': 15},
#   'text': 'iOS 6 is not inferior to Android.'},
#  {'CAM_score': 0.7330404624383481,
#   'ES_score': 44.76071,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://technable.net/woz-would-love-to-see-itunes-for-android-also-jailbreaking-community-reminds-him-of-his-youth/': 10,
#    'http://www.androidauthority.com/woz-would-love-see-itunes-android-also-jailbreaking-community-reminds-him-youth-119647/': 10},
#   'text': 'But neither is Android inferior to iOS!'},
#  {'CAM_score': 0.7329209767730414,
#   'ES_score': 44.753414,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.osnews.com/comments/25264': 258,
#    'http://www.osnews.com/thread?494598': 11,
#    'http://www.osnews.com/thread?494603': 6},
#   'text': 'Yeah, Android is empirically inferior to iOS.'},
#  {'CAM_score': 0.7276185710988348,
#   'ES_score': 44.42964,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.wired.com/2012/04/easier-design-apps-ios/': 1},
#   'text': 'Why iOS Apps Look Better Than Android Apps .'},
#  {'CAM_score': 0.7239101919798588,
#   'ES_score': 44.2032,
#   'confidence': 1,
#   'context_aspects': ['richer'],
#   'id_pair': {'http://www.androidauthority.com/10-reasons-why-android-is-still-better-than-ios-145370/': 1058},
#   'text': 'roughly thinking that android user are poorer than ios user, so they charge differently, buy android and ios, enjoy both of the worlds.'},
#  {'CAM_score': 0.7224262343879679,
#   'ES_score': 44.112587,
#   'confidence': 1,
#   'context_aspects': ['faster', 'faster'],
#   'id_pair': {'http://www.zdnet.com/article/windows-phone-wednesday-100000-apps-published-to-the-marketplace/': 5},
#   'text': 'This is faster than Android (24 months) and slower than iOS (16 months).'},
#  {'CAM_score': 0.7187325944546795,
#   'ES_score': 43.887047,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://macdailynews.com/2013/01/30/ios-apps-are-better-than-their-android-counterparts/': 15},
#   'text': 'Yet as the article mentions, the counter part mobile programs on Android are inferior to Apple iOS apps.'},
#  {'CAM_score': 0.714932684992584,
#   'ES_score': 43.655018,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://toucharcade.com/2014/03/25/portal-coming-to-android/': 98},
#   'text': 'Ios is much better in graphics than android and smoother.'},
#  {'CAM_score': 0.697958580202411,
#   'ES_score': 42.61855,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://forums.macrumors.com/threads/why-is-the-iphone-better-than-android-phones.1464667/': 13},
#   'text': "It's a lot more intuitive so that is why the apps for iOS are a lot better than android."},
#  {'CAM_score': 0.6975104598268919,
#   'ES_score': 42.591187,
#   'confidence': 1,
#   'context_aspects': ['smoother', 'smoother'],
#   'id_pair': {'http://www.anandtech.com/Show/Index/4951?cPage=3&all=False&sort=0&page=1&slug=iphone-4s-preliminary-benchmarks-800mhz-a5-slightly-slower-gpu-than-ipad-2': 33,
#    'http://www.anandtech.com/comments/4951/iphone-4s-preliminary-benchmarks-800mhz-a5-slightly-slower-gpu-than-ipad-2': 42},
#   'text': 'WP7 and iOS devices on 2010 hardware are much smoother than even the latest Android handsets.'},
#  {'CAM_score': 0.6974421682665398,
#   'ES_score': 42.587017,
#   'confidence': 1,
#   'context_aspects': ['easier to use', 'easier', 'easier to use', 'easier'],
#   'id_pair': {'http://www.phonearena.com/news/Survey-says-that-the-Samsung-Galaxy-Series-is-simpler-than-the-Apple-iPhone_id41712': 28,
#    'http://www.phonearena.com/news/Survey-says-that-the-Samsung-Galaxy-Series-is-simpler-than-the-Apple-iPhone_id41712/comments': 7},
#   'text': 'In my personal experience iOS is way easier to use than android.'},
#  {'CAM_score': 0.6862635276655662,
#   'ES_score': 41.90443,
#   'confidence': 1,
#   'context_aspects': ['faster', 'faster'],
#   'id_pair': {'http://www.gottabemobile.com/2012/06/05/windows-phone-marketplace-surpasses-100000-apps/': 6},
#   'text': 'Microsoft managed to reach the 100,000 apps milestone faster than Android, but slower than iOS .'},
#  {'CAM_score': 0.6820155633354437,
#   'ES_score': 41.645042,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://modmyi.com/forums/iphone-news/821041-study-reveals-iphone-5-users-galaxy-s-iii-users-quite-alike-4.html': 252},
#   'text': 'how is iOS superior to Android.'},
#  {'CAM_score': 0.6819226082043746,
#   'ES_score': 41.639366,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.eweek.com/c/a/Mobile-and-Wireless/Verizon-iPhone-5-Will-Beat-Any-Android-Handset-10-Reasons-Why-239783/1': 1},
#   'text': 'Apple iOS Still Superior to Android .'},
#  {'CAM_score': 0.6816077464443434,
#   'ES_score': 41.62014,
#   'confidence': 1,
#   'context_aspects': ['easier to use', 'easier'],
#   'id_pair': {'http://lifelibertytech.com/2013/01/28/life-is-hard-android-is-harder/': 82},
#   'text': "It's about the myth of iOS being easier to use than android."},
#  {'CAM_score': 0.6752213391703129,
#   'ES_score': 41.230175,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.xda-developers.com/ios-is-superior-xda-changing-focus/': 6},
#   'text': 'iOS is simply better than Android.'},
#  {'CAM_score': 0.6751473975887805,
#   'ES_score': 41.22566,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.droid-life.com/2012/10/12/video-need-50-reasons-why-your-galaxy-s3-is-better-than-the-new-iphone/comment-page-1/': 75},
#   'text': 'iOS is a simpler OS in comparison to Android.'},
#  {'CAM_score': 0.6703622063172215,
#   'ES_score': 40.933468,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.androidcentral.com/unreal-engine-3-now-running-android-too-video': 23},
#   'text': 'It is pretty much "inferior" to iOS gaming.'},
#  {'CAM_score': 0.6585459976740256,
#   'ES_score': 40.21195,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.androidauthority.com/five-reasons-android-killing-apple-234364/': 962},
#   'text': '2) iOS is far superior to Android.'},
#  {'CAM_score': 0.6558625815277586,
#   'ES_score': 40.048096,
#   'confidence': 1,
#   'context_aspects': ['faster', 'faster'],
#   'id_pair': {'http://www.feld.com/archives/2013/12/month-android-instead-ios.html': 429},
#   'text': 'Android recharge is generally way slower than iOS and burns battery a lot faster!'},
#  {'CAM_score': 0.653984334341854,
#   'ES_score': 39.933407,
#   'confidence': 1,
#   'context_aspects': ['faster', 'faster'],
#   'id_pair': {'http://allaboutwindowsphone.com/news/item/16023_125000_apps_published_to_Windo.php': 12},
#   'text': 'Windows Phone reached the 125,000 milestone faster than Android (26 months), but slower than iOS (18.5 months) .'},
#  {'CAM_score': 0.6539699718242451,
#   'ES_score': 39.93253,
#   'confidence': 1,
#   'context_aspects': ['faster', 'faster', 'faster', 'faster'],
#   'id_pair': {'http://allaboutwindowsphone.com/news/item/14960_100000_apps_published_to_Windo.php': 11,
#    'http://www.businessinsider.com/the-microsoft-investor-june-7-2012-6': 22},
#   'text': 'Windows Phone reached the 100,000 milestone faster than Android (24 months), but slower than iOS (16 months) .'},
#  {'CAM_score': 0.6537493753451221,
#   'ES_score': 39.91906,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.idownloadblog.com/2013/07/07/iphone-mac-pro-moment/': 250},
#   'text': "It's true iOS smoother than Android but is getting a little bit better."},
#  {'CAM_score': 0.6468866139665445,
#   'ES_score': 39.500008,
#   'confidence': 1,
#   'context_aspects': ['smoother', 'smoother'],
#   'id_pair': {'http://www.psu.com/forums/printthread.php?t=213324&pp=25&page=112': 6,
#    'http://www.psu.com/forums/showthread.php/213324-Android-Phone-Thread/page112?p=5909712': 9},
#   'text': 'IOS is smoother than Android.'},
#  {'CAM_score': 0.6461281846016844,
#   'ES_score': 39.453697,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.businessinsider.com/ios-7-adoption-rate-greater-than-android-2013-9': 1},
#   'text': "It's Been Less Than 24 Hours And Apple's iOS 7 Already Has A Faster Adoption Rate Than Google's Latest Version Of Android ."},
#  {'CAM_score': 0.640410494182296,
#   'ES_score': 39.104565,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://ceklog.kindel.com/2012/03/31/google-will-abandon-android/': 50},
#   'text': 'Saying Nexus devices are inferior to iOS makes no sense.'},
#  {'CAM_score': 0.6398254959023589,
#   'ES_score': 39.068844,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.geek.com/mobile/ios-has-10x-more-security-holes-than-android-but-its-still-safer-says-symantec-1396393/': 7},
#   'text': "Ultimately, however, iOS fares better than Android in Symantec's overall analysis."},
#  {'CAM_score': 0.6366084557267124,
#   'ES_score': 38.872406,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://bgr.com/2011/10/20/samsung-takes-smartphone-crown-in-q3-as-shipments-top-apple-nokia/': 126},
#   'text': 'to show that ios is superior to android.'},
#  {'CAM_score': 0.6361582063577051,
#   'ES_score': 38.844913,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://venturebeat.com/2012/03/05/apples-ios-runs-html5-games-three-times-faster-than-android/': 12},
#   'text': 'Repeated tests show that iOS performed far better at running animations than Android.'},
#  {'CAM_score': 0.6310858629952076,
#   'ES_score': 38.535187,
#   'confidence': 1,
#   'context_aspects': ['easier'],
#   'id_pair': {'http://www.laptopmag.com/articles/iphone-4s-vs-android-phones-whats-better-for-you': 219},
#   'text': "It's true, IOS has a much easier interface than the android OS."},
#  {'CAM_score': 0.6280709298090826,
#   'ES_score': 38.35109,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.techspot.com/news/47672-apples-ios-runs-html5-games-three-times-faster-than-android.html': 11},
#   'text': 'The report concluded that iOS offers around three times better HTML 5 performance than Android.'},
#  {'CAM_score': 0.6251717319843506,
#   'ES_score': 38.17406,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.patentlyapple.com/patently-apple/2012/11/will-apple-lead-or-follow-in-the-future-glass-projects-market.html': 88},
#   'text': "Google's Android in my view, is inferior to iOS on appearance alone."},
#  {'CAM_score': 0.6250826417953061,
#   'ES_score': 38.16862,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://bgr.com/2011/02/13/sony-ericsson-xperia-play-finally-announced/': 54},
#   'text': 'Android is inferior to Webos, and IOS and always will be period.'},
#  {'CAM_score': 0.6236630944448698,
#   'ES_score': 38.08194,
#   'confidence': 1,
#   'context_aspects': ['smoother'],
#   'id_pair': {'http://forums.macrumors.com/threads/whats-going-to-be-the-crazy-rumor-and-most-notable-moment-for-the-iphone-5s.1514819/': 101},
#   'text': 'iOS is still smoother than Android.'},
#  {'CAM_score': 0.6236448506083632,
#   'ES_score': 38.080826,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://blogs.wsj.com/indiarealtime/2012/09/27/tech-journal-where-android-is-better-than-apples-ios/?mod=WSJ_qtoverview_wsjlatest': 38,
#    'http://blogs.wsj.com/indiarealtime/2012/09/27/tech-journal-where-android-is-better-than-apples-ios/tab/comments/': 55},
#   'text': 'With added security in iOS it really feels safer on Apple devices than on Android devices.'},
#  {'CAM_score': 0.6219007791428338,
#   'ES_score': 37.97433,
#   'confidence': 1,
#   'context_aspects': ['smoother',
#    'smoother',
#    'smoother',
#    'smoother',
#    'smoother',
#    'smoother',
#    'smoother'],
#   'id_pair': {'http://www.dailytech.com/Microsoft+Rolls+Out+First+Major+Windows+Phone+7+Update+Adds+CopyPaste/article21201.htm': 53,
#    'http://www.dailytech.com/article.aspx?newsid=21201&commentid=665897&threshhold=1&red=4357': 53,
#    'http://www.dailytech.com/article.aspx?newsid=21201&commentid=665897&threshhold=1&red=556': 53,
#    'http://www.dailytech.com/article.aspx?newsid=21201&commentid=665903&threshhold=1&red=2129': 53,
#    'http://www.dailytech.com/article.aspx?newsid=21201&commentid=665903&threshhold=1&red=2638': 53,
#    'http://www.dailytech.com/article.aspx?newsid=21201&commentid=665911&threshhold=1&red=1342': 44,
#    'http://www.dailytech.com/article.aspx?newsid=21201&commentid=665937&threshhold=1&red=1352': 36},
#   'text': 'WP7 on Snapdragon or iOS on A4 is much smoother than Android on the technically faster Hummingbird.'},
#  {'CAM_score': 0.6199239268046798,
#   'ES_score': 37.85362,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.cultofmac.com/254059/android-users-defecting-to-iphone-in-greater-and-greater-numbers/': 64},
#   'text': "I can't claim that iOS is objectively better than Android, but iOS just works better - for me - in the ways that are important to me."},
#  {'CAM_score': 0.6188437082625157,
#   'ES_score': 37.78766,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.geek.com/apple/google-apps-run-better-on-the-ipad-mini-than-the-nexus-7-1531867/': 9},
#   'text': "In summary, there's quite a few Google Apps on iOS, and several of the recently updated ones are much nicer on iOS than on Android."},
#  {'CAM_score': 0.6161927838322532,
#   'ES_score': 37.62579,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.phonearena.com/news/No-contract-pricing-for-the-Apple-iPhone-4S-is-revealed---starts-at-649_id22713': 44,
#    'http://www.phonearena.com/news/No-contract-pricing-for-the-Apple-iPhone-4S-is-revealed---starts-at-649_id22713/comments': 38},
#   'text': 'iOS will always, ALWAYS, be far superior to Android.'},
#  {'CAM_score': 0.6110979386462726,
#   'ES_score': 37.31469,
#   'confidence': 1,
#   'context_aspects': ['faster', 'faster'],
#   'id_pair': {'https://en.wikipedia.org/wiki/Windows_Phone_Marketplace': 31},
#   'text': 'The growth to achieve 100,000 apps is faster than Android with 24 months, but slower than iOS with 16 months.'},
#  {'CAM_score': 0.6109051337206071,
#   'ES_score': 37.302917,
#   'confidence': 1,
#   'context_aspects': ['faster', 'faster'],
#   'id_pair': {'http://delphi.org/2013/11/8-tips-to-speed-up-your-android-arm-emulator-avd/': 4},
#   'text': 'This means the iOS Simulator is typically faster than actual hardware, and the Android Emulator is slower than actual hardware.'},
#  {'CAM_score': 0.6090201556399052,
#   'ES_score': 37.187817,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.unwiredview.com/2012/03/08/samsung-suggests-the-galaxy-note-10-1-is-better-than-apples-new-ipad-when-it-comes-to-content-creation/': 16},
#   'text': 'Not to mention the fact that many see iOS as being superior to Android 4.0 Ice Cream Sandwich.'},
#  {'CAM_score': 0.6085339262809474,
#   'ES_score': 37.158127,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://venturebeat.com/2012/03/05/apples-ios-runs-html5-games-three-times-faster-than-android/': 8},
#   'text': 'iOS performed three times better at running HTML5 games than Android, according to the new study.'},
#  {'CAM_score': 0.6082322479036701,
#   'ES_score': 37.139706,
#   'confidence': 1,
#   'context_aspects': ['easier to implement highly detailed app design',
#    'easier',
#    'easier to implement highly detailed app design',
#    'easier'],
#   'id_pair': {'http://www.gizmodo.co.uk/2012/04/why-ios-apps-look-better-than-android-apps/': 43,
#    'http://www.gizmodo.com.au/2012/05/why-ios-apps-look-better-than-android-apps/': 39},
#   'text': 'Although iOS makes it easier to implement highly detailed app design, Android offers more freedom with what you can do.'},
#  {'CAM_score': 0.6076073228073929,
#   'ES_score': 37.101547,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://forums.macrumors.com/threads/my-week-with-the-nexus-7.1459023/': 27},
#   'text': 'I had read that the apps on Android were inferior to iOS apps.'},
#  {'CAM_score': 0.6076073228073929,
#   'ES_score': 37.101547,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.animoca.com/en/2012/05/the-varieties-of-android-experience/': 84},
#   'text': 'There have been some reports that Android monetization is inferior to iOS monetization.'},
#  {'CAM_score': 0.6075894556389652,
#   'ES_score': 37.100456,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://arstechnica.com/tech-policy/2011/12/is-apple-is-using-patents-to-hurt-open-standards/?comments=1&start=120': 64,
#    'http://arstechnica.com/tech-policy/2011/12/is-apple-is-using-patents-to-hurt-open-standards/?comments=1&start=40': 70},
#   'text': 'In its core architecture, 5 years later, Android OS remains inferior to iOS.'},
#  {'CAM_score': 0.6074403933410456,
#   'ES_score': 37.091354,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.amazon.co.uk/Nighty-Night-Bedtime-story-children/dp/B008UAOQFW': 28},
#   'text': 'This is great but the Android version is very inferior to the IoS.'},
#  {'CAM_score': 0.6073295055340566,
#   'ES_score': 37.084583,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://bgr.com/2010/11/18/wozniak-misquoted-ios-still-rules/': 147},
#   'text': "Now, I'm not saying that Android is inferior to iOS by any means."},
#  {'CAM_score': 0.6034039690792847,
#   'ES_score': 36.844883,
#   'confidence': 1,
#   'context_aspects': ['smoother', 'simpler', 'os'],
#   'id_pair': {'http://www.phonearena.com/news/iPhone-users-admit-to-blind-loyalty-to-Apple_id52603': 139},
#   'text': "iOS is smoother than Android because of this, and because it's a simpler OS with a LOT less going on."},
#  {'CAM_score': 0.6026353532994273,
#   'ES_score': 36.79795,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.cultofmac.com/254059/android-users-defecting-to-iphone-in-greater-and-greater-numbers/': 30},
#   'text': 'Honestly, I love the form factor of the Samsung phones, but I like the iOS better than Android.'},
#  {'CAM_score': 0.602488239849393,
#   'ES_score': 36.788967,
#   'confidence': 1,
#   'context_aspects': ['safer'],
#   'id_pair': {'https://www.sophos.com/en-us/security-news-trends/security-trends/malware-goes-mobile/why-ios-is-safer-than-android.aspx': 3},
#   'text': 'Why iOS is safer than Android .'},
#  {'CAM_score': 0.6024347038516014,
#   'ES_score': 36.785698,
#   'confidence': 1,
#   'context_aspects': ['smoother'],
#   'id_pair': {'https://www.androidpit.com/3-ways-apple-could-make-android-better': 14},
#   'text': 'Call me an Apple fanboy if you like, but the truth is that iOS generally runs smoother than Android.'},
#  {'CAM_score': 0.5992231007977863,
#   'ES_score': 36.589592,
#   'confidence': 1,
#   'context_aspects': ['easier to use and to figure out', 'easier'],
#   'id_pair': {'http://www.phonedog.com/2011/05/23/is-the-iphone-all-that-much-simpler-than-android': 7},
#   'text': 'Most users automatically assume the iPhone platform, or iOS, is much easier to use and to figure out than Android because that is what they have been told.'},
#  {'CAM_score': 0.5978780354656906,
#   'ES_score': 36.50746,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'https://plus.google.com/+SlashGear/posts/g4TYYSbg7Rd': 12},
#   'text': "Notice I never said that iOS is superior to Android, I wasn't picking a fight, I simply said that Android definitely isn't superior to iOS."},
#  {'CAM_score': 0.5977914673150859,
#   'ES_score': 36.502174,
#   'confidence': 1,
#   'context_aspects': ['faster', 'faster'],
#   'id_pair': {'http://bgr.com/2012/08/28/apple-samsung-patent-trial-analysis-windows-phone/': 6},
#   'text': 'But Windows Phone hit the 100,000 mark in 20 months - four months faster than Android and four months slower than iOS.'},
#  {'CAM_score': 0.5977353929019816,
#   'ES_score': 36.49875,
#   'confidence': 1,
#   'context_aspects': ['faster', 'faster'],
#   'id_pair': {'http://www.dcemu.co.uk/vbulletin/threads/461377-Windows-Phone-Marketplace-surpasses-100-000-app-submissions': 5},
#   'text': 'The Marketplace reached this mark five months faster than the Android Market , but three months slower than the iOS App Store .'},
#  {'CAM_score': 0.5970223110984201,
#   'ES_score': 36.455208,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.product-reviews.net/2012/11/08/ios-6-untethered-jailbreak-wait-equals-iphone-5-deserters/': 130},
#   'text': 'The iOS operating system is by far superior to Android.'},
#  {'CAM_score': 0.5970223110984201,
#   'ES_score': 36.455208,
#   'confidence': 1,
#   'context_aspects': [],
#   'id_pair': {'http://www.metafilter.com/138244/So-Android-phones-turn-out-to-be-too-working-class-to-be-interesting': 271},
#   'text': 'For a long time, iOS was far superior to Android.'}]

# %% [markdown]
# #### Json structure:
# ```
# {
#     'extractedAspectsObject1' - list with aspects for object1,
#     'extractedAspectsObject2' - list with aspects for object2,
#     'object1': {
#         'name',
#         'points',
#         'sentences': [{
#             "CAM_score",
#             "ES_score",
#             "confidence",
#             "context_aspects": ["greater"],
#             "id_pair": {
#                 "http://www.womansday.com/life/pet-care/news/a45352/study-decides-who-is-smarter-a-dogs-or-cats-1342/": 5
#              },
#              "text": "A study that analyzed data of the brain versus the body size of both animals, found that the brain of the pack-animal dog has evolved at a much greater rate than the brain of the less-social cat."
#         }]
#     },
#     'object2',
#     'sentenceCount',
#     'winner'
# }
# ```

# %%
'''
'{} is better than {} because it is {}'
''' 

def get_first_template(comparison_result):
    template = '{} is better than {} because it is {}'
    
    winner = comparison_result['winner']
    winner_object_number = 1 if comparison_result['object1']['name'] == winner else 2
    loser_object_number = 3 - winner_object_number
    loser = comparison_result['object' + str(loser_object_number)]['name']
    aspect = comparison_result['extractedAspectsObject' + str(winner_object_number)][0] 
    
    return template.format(winner.capitalize(), loser, aspect)

# %%
get_first_template(response_json)
# Out:
# 'Cat is better than dog because it is easier to take care of'

# %%
'''
'Both objects have some advantages: {} is {}, than {} is {}. But I would prefer {}'
'''

def get_second_template(comparison_result):
    template = 'Both objects have some advantages: {} is {}, than {} is {}. But I would prefer {}'
    return template.format(
        comparison_result['object1']['name'],
        ', '.join(comparison_result['extractedAspectsObject1']),
        comparison_result['object2']['name'],
        ', '.join(comparison_result['extractedAspectsObject2']),
        comparison_result['winner']
    )

# %%
# '''
# 'There are some aspects to pay attention to while making your choice:  I would prefer {} to {}'
# '''

# def get_fourth_template(first_object, second_object, comparison_result):
    
#     return SECOND_TEMPLATE.format(
#         comparison_result['object1']['name'],
#         ', '.join(comparison_result['extractedAspectsObject1']),
#         comparison_result['object2']['name'],
#         ', '.join(comparison_result['extractedAspectsObject2']),
#         comparison_result['winner'],
#         second_object if comparison_result['winner'] == first_object else first_object
#     )

# %%
get_second_template(response_json)
# Out:
# 'Both objects have some advantages: dog is easier for it to demonstrate its intelligence, poop, better for you, acids, dogs, longer, easier to write about a dog, zeke, cats, easier to identify, than cat is easier to take care of, smarter, greater, quicker, safer, lighter, bigger, bit, cleverer, baby. But I would prefer cat'

# %%
from tqdm import tqdm_notebook

# %%
pairs_without_aspects = [
    ('dog', 'cat'),
    ('cuda', 'opencl'),
    ('ios', 'android'),
    ('potato', 'steak'),
    ('pepsi', 'coca-cola'),
    ('milk', 'beer'),
    ('php', 'javascript'),
    ('python', 'java'),
    ('perl', 'python'),
]

# %%
results_for_pairs = {}
for pair in tqdm_notebook(pairs_without_aspects):
    comparison_result = get_response(*pair, False).json()
    results_for_pairs[pair] = comparison_result
# Out:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))

# %%
for pair in pairs_without_aspects:
    comparison_result = results_for_pairs[pair]
    print(get_first_template(comparison_result))
    print(get_second_template(comparison_result))
    print("")
# Out:
# Cat is better than dog because it is easier to take care of
# Both objects have some advantages: dog is easier for it to demonstrate its intelligence, poop, better for you, acids, dogs, longer, easier to write about a dog, zeke, cats, easier to identify, than cat is easier to take care of, smarter, greater, safer, lighter, quicker, bit, cleverer, baby, litter. But I would prefer cat
#
# Cuda is better than opencl because it is easier for the developer
# Both objects have some advantages: cuda is easier for the developer, faster, thats, easier to learn, nature, easier to use, higher, greater, ofcourse, easier to program, than opencl is easier to program for, simpler to target cuda, simpler, earlier, older, performance. But I would prefer cuda
#
# Android is better than ios because it is easier to setup the actual tools i ve found but once thats done it s easier to code
# Both objects have some advantages: ios is richer, phone, windows, state, webos, smoother, apps, malware, bigger, easier to use, than android is easier to setup the actual tools i ve found but once thats done it s easier to code, easier to code, ther, earlier, smarter, easier to do when developing for ios, apis, easier to implement in ios because of the wide variety of apis and libraries available, variety, libraries. But I would prefer android
#
# Steak is better than potato because it is faster
# Both objects have some advantages: potato is happiness, sam, basket, wealthier, than steak is faster, better for them, larger, better for its creamy potato gratin side. But I would prefer steak
#
# Coca-cola is better than pepsi because it is brand
# Both objects have some advantages: pepsi is germany, greater, logo, cocacola, easier, earlier, carbonation, taxes, drink, loyalty, than coca-cola is brand, faster, stronger, cooler, awareness, affinity, better to pay more for a coke or a pepsi, more for a coke or a pepsi, richer. But I would prefer coca-cola
#
# Beer is better than milk because it is greater
# Both objects have some advantages: milk is worse for children, sugar, none, nutrients, easier to get, better for all the family, skim, higher, than beer is greater, lighter, safer, smoother, faster, safer to drink, stronger, cheaper, easier, better for my health. But I would prefer beer
#
# Javascript is better than php because it is faster
# Both objects have some advantages: php is easier to learn, easier to pick up for a noob, java, easier, characters, greater, traction, websites, uis, than javascript is faster, easier to understand, animation, faster to serve the static file, processing, form, files, easier to write terrible code, quicker, languages. But I would prefer javascript
#
# Python is better than java because it is simpler
# Both objects have some advantages: python is simpler, easier to read and work with, greater, details, harder, lists, dictionaries, form, easier to learn, easier to program in, than java is larger, better for socalled algorithm refinement, perl, ruby, heavier, types, development, garbage, collection, times. But I would prefer python
#
# Python is better than perl because it is easier to read
# Both objects have some advantages: perl is bindings, speed, ruby, ease, lambdas, recursion, cooler, statement, brain, faster, than python is easier to read, easier to learn, easier, simpler, syntax, easier to maintain, lisp, easier to understand, easier to parse, easier to test. But I would prefer python

# %%
'''
I would prefer {} to {} because it is {}. The argument which proved it was on {}: \"{}\"
'''

def find_sentences_with_aspect(aspect, sentences):
    sentences = np.array(sentences)
    indices = np.where([aspect in sentence["context_aspects"] for sentence in sentences])[0]
    return sentences[indices]

    
def get_third_template(comparison_result):
    winner = comparison_result['winner']
    winner_object_number = 1 if comparison_result['object1']['name'] == winner else 2
    loser_object_number = 3 - winner_object_number
    loser = comparison_result['object' + str(loser_object_number)]['name']
    aspect = comparison_result['extractedAspectsObject' + str(winner_object_number)][0] 
    winner_sentences = comparison_result['object' + str(winner_object_number)]['sentences']    
    sentence = find_sentences_with_aspect(aspect, winner_sentences)[0]
    
    first_word = aspect.split(' ')[0]
    is_comparative = (first_word[-2:] == "er")
    if is_comparative:
        template = "I would prefer {} to {} because it is {}. " 
    else:
        template = "I would prefer {} to {} because its {}. "
    
    template += "The argument which proved it was on {}: \"{}\"" 
        
    url = next(iter(sentence['id_pair']))  
    
    return template.format(
        winner,
        loser,
        aspect,
        url,
        sentence['text']
    )

# %%
get_third_template(response_json)
# Out:
# 'I would prefer cat to dog because it is easier to take care of. The argument which proved it was on https://www.reddit.com/r/aww/comments/q57yb/most_people_have_to_fight_cats_off_their_laptops/: "I would say harder to take care of than a cat, but easier than a dog that you need to walk several times a day."'

# %%
for pair in pairs_without_aspects:
    comparison_result = results_for_pairs[pair]
    print(get_third_template(comparison_result))
    print("")
# Out:
# I would prefer cat to dog because it is easier to take care of. The argument which proved it was on https://www.reddit.com/r/aww/comments/q57yb/most_people_have_to_fight_cats_off_their_laptops/: "I would say harder to take care of than a cat, but easier than a dog that you need to walk several times a day."
#
# I would prefer cuda to opencl because it is easier for the developer. The argument which proved it was on http://streamcomputing.eu/blog/2010-04-22/difference-between-cuda-and-opencl/: "In short CUDA certainly has made a lot of things just easier for the developer, but OpenCL has its potential in support for more than just GPUs."
#
# I would prefer android to ios because it is easier to setup the actual tools i ve found but once thats done it s easier to code. The argument which proved it was on http://crackberry.com/comment/1066683: "BB is harder to setup the actual tools I've found but once thats done it's easier to code than Android and provides better integration and power than iOS."
#
# I would prefer steak to potato because it is faster. The argument which proved it was on http://www.westword.com/news/a-clean-break-5062803: "But then, eating a thick steak helps you recover faster than eating potato chips."
#
# I would prefer coca-cola to pepsi because its brand. The argument which proved it was on http://www.newbrewmedia.com/: "Hey, let's rank Coca-Cola a little higher because they seem to have greater brand awareness, brand affinity than Pepsi."
#
# I would prefer beer to milk because it is greater. The argument which proved it was on http://www.scstatehouse.gov/sess111_1995-1996/sj95/19950113.htm: "In fact, the per capita consumption of beer is greater than the per capita consumption of milk each year."
#
# I would prefer javascript to php because it is faster. The argument which proved it was on http://www.dev102.com/2008/09/16/developing-php-on-your-visual-studio-20082005/: "auto complete is much faster, html, css and javascript, although still quite poor in VS, is much nicer to read than in eclipse... With good auto complete in VS for php, I find it much better than eclipse."
#
# I would prefer python to java because it is simpler. The argument which proved it was on http://www.osnews.com/comments/14623: "Python is much simpler and more compact than Java."
#
# I would prefer python to perl because it is easier to read. The argument which proved it was on https://www.linuxquestions.org/questions/programming-9/perl-vs-python-468880/: "It's also a heck of a lot easier to read than Perl."
